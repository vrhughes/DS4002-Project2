# %% [markdown]
# <a href="https://colab.research.google.com/github/vrhughes/DS4002-Project2/blob/main/GDP_csv_organizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing packages
import pandas as pd
import re

# %%
# CLoning the repo
! git clone https://github.com/vrhughes/DS4002-Project2
# Out:
# fatal: destination path 'DS4002-Project2' already exists and is not an empty directory.

# %%
# Reading in the data
gdp_df = pd.read_csv('/content/DS4002-Project2/DATA/GDP-Per-Capita-Current-USD.csv')

# %%
# Reorganizing data so it matches the other datasets and files

# Ensure consistency in GDP dataset column names
gdp_df.rename(columns={'Country Name': 'Country'}, inplace=True)

# Identify the year columns in GDP data
year_cols = [col for col in gdp_df.columns if re.search(r'\b\d{4}\b', col)]

# Reshape GDP data from wide to long format
gdp_df = gdp_df.melt(id_vars=['Country'], value_vars=year_cols, var_name='Year', value_name='GDP_Per_Capita')

# Convert Year to numeric to match other datasets
gdp_df['Year'] = gdp_df['Year'].str.extract(r'(\b\d{4}\b)').astype(int)

# %%
# Output gdp_df to see how it looks
gdp_df
# Out:
#          Country  Year GDP_Per_Capita
# 0          Chile  1974    1542.925527
# 1     Bangladesh  1974    164.9863936
# 2          Nauru  1974    5199.264975
# 3      Nicaragua  1974    556.8661225
# 4         Norway  1974    6811.527337
# ...          ...   ...            ...
# 1045         NaN  2023            NaN
# 1046         NaN  2023            NaN
# 1047         NaN  2023            NaN
# 1048         NaN  2023            NaN
# 1049         NaN  2023            NaN
#
# [1050 rows x 3 columns]

# %%
# Exporting data
gdp_df.to_csv('gdp_df.csv', index=False)
